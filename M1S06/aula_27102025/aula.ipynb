# %%
import numpy as np

a1D = np.array([1, 2, 3, 4, 5])

a2D = np.array([[1, 2, 3],
                [4, 5, 6]])

a3D = np.array([[[1, 2], [3, 4]],
                [[5, 6], [7, 8]]])

print(a1D.shape)
print(a2D.shape)
print(a3D.shape)
# Out:
# (5,)
# (2, 3)
# (2, 2, 2)
